        0.951579804672581,0.951579804672581,0.950359957470961,0.992047987783155,1.29239531031577,1.00802346832019,
        1.43787116325946,0.902570939327272,0.902041685839419,0.90627900856072,1.09494548834253,1.26451665273977,
        1.06925717451411,0.955900856935889,0.984699032842826,0.947829932460147,0.9236539459508,1.13608462495016
    ],
    "Final Submission": [
        1.36212321826012,1.36786609936706,1.0,1.04689160452168,1.01463811814601,0.921110363223833,0.913404449218904,
        0.905087844862613,0.904521986576064,1.02891462627876,0.911741989407571,0.902161201058215,0.905408161492384,
        0.902645016779531,0.972324150359623,0.902161201058215
    ],
    "Raptus": [
        1.0,5.74986724027655,87.3430332901766,0.978892709009889,0.979082984123394,1.40891153611098,0.94262584362474,
        0.912019765929777,0.908780269984597,0.941922563492593,0.943395611272048,0.94232313982561,0.909209727406127,
        0.909222197975105,0.907706279913548,0.906932375590016,0.908905908566917,1.97798204751825,0.906244938424295,
        0.921596974639173,0.906239849762023,0.905477866300664
    ],
    "sorochilco": [
        2.54196066713217,4.12445669204917,0.917950444674689,0.945436579230785,0.915088416770767,0.919476294431988,
        0.913667831987119,0.913667831987119,0.915962647983791,0.925613266181923,0.914961216842422,0.908085977382714,
        0.908939607826842,0.90671865065788,0.906360246906649,0.907639117155532,9.2696658632702,0.937463350034153,
        0.906360246906649
    ],
}

# %% [markdown]
# ### Stat

# %%
for key in list(data.keys()):
    print(f"Team Name: {key}, sumission len: {len(data[key])}, avg MAE: {round(sum(data[key])/len(data[key]), 2)}")
# Out:
# Team Name: AfterParty, sumission len: 21, avg MAE: 1.91
# Team Name: Prada.ai, sumission len: 22, avg MAE: 2.3
# Team Name: Profesiyni Shatuni Tablic, sumission len: 24, avg MAE: 0.97
# Team Name: Hack4reMONT, sumission len: 15, avg MAE: 1.24
# Team Name: One_More_Mistake, sumission len: 13, avg MAE: 0.99
# Team Name: Tiger Analytics, sumission len: 32, avg MAE: 1.04
# Team Name: julia110995, sumission len: 61, avg MAE: 1.32
# Team Name: Final Submission, sumission len: 16, avg MAE: 1.0
# Team Name: Raptus, sumission len: 22, avg MAE: 5.15
# Team Name: sorochilco, sumission len: 19, avg MAE: 1.61

# %% [markdown]
# ### Import

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
teams = list(data.keys())
teams
# Out:
# ['AfterParty',
#  'Prada.ai',
#  'Profesiyni Shatuni Tablic',
#  'Hack4reMONT',
#  'One_More_Mistake',
#  'Tiger Analytics',
#  'julia110995',
#  'Final Submission',
#  'Raptus',
#  'sorochilco']

# %%
fig = make_subplots(
    rows=5, cols=2, 
    subplot_titles=[f"Team Name: {team}" for team in teams]
)

fig.add_trace(
    go.Scatter(y=data[teams[0]], line=dict(color="rgb(67,67,67)")),
    row=1, col=1,
)

fig.add_trace(
    go.Scatter(y=data[teams[1]], line=dict(color="rgb(67,67,67)")),
    row=1, col=2
)

fig.add_trace(
    go.Scatter(y=data[teams[2]], line=dict(color="rgb(67,67,67)")),
    row=2, col=1
)

fig.add_trace(
    go.Scatter(y=data[teams[3]], line=dict(color="rgb(67,67,67)")),
    row=2, col=2
)

fig.add_trace(
    go.Scatter(y=data[teams[4]], line=dict(color="rgb(67,67,67)")),
    row=3, col=1
)

fig.add_trace(
    go.Scatter(y=data[teams[5]], line=dict(color="rgb(67,67,67)")),
    row=3, col=2
)

fig.add_trace(
    go.Scatter(y=data[teams[6]], line=dict(color="rgb(67,67,67)")),
    row=4, col=1
)

fig.add_trace(
    go.Scatter(y=data[teams[7]], line=dict(color="rgb(67,67,67)")),
    row=4, col=2
)


fig.add_trace(
    go.Scatter(y=data[teams[8]], line=dict(color="rgb(67,67,67)")),
    row=5, col=1
)

fig.add_trace(
    go.Scatter(y=data[teams[9]], line=dict(color="rgb(67,67,67)")),
    row=5, col=2
)


fig.update_layout(height=600, width=800, title_text="Top 10 teams submisions progress")

for i in fig['layout']['annotations']:
    i['font'] = dict(size=10,color='rgb(67,67,67)')

fig.show()
# Out:
# <div>                            <div id="16071997-62a6-4d20-98c5-1280a413dafe" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16071997-62a6-4d20-98c5-1280a413dafe")) {                    Plotly.newPlot(                        "16071997-62a6-4d20-98c5-1280a413dafe",                        [{"line":{"color":"rgb(67,67,67)"},"y":[11.5922856904628,1.51388411236785,3.8404799176045,0.952672086630978,0.980810145614286,0.938583779541549,6.94086197828516,0.80058799164289,0.80058799164289,0.957183375429288,0.89023019176361,0.933256336874587,1.40661378833,2.06805884992326,0.760033771959681,0.91128022465628,0.78595507541147,0.751803615214252,0.759867902553734,0.74821524914462,0.74821524914462],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"rgb(6
# ...

# %%
# N = 5
# upd_data = dict()
# for item in list(data.keys()):
#     upd_val = []
#     for val in data[item]:
#         if val < N:
#             upd_val.append(val)
#     upd_data[item] = upd_val

# data = upd_data

# %%
SUB_COUNT = 5

fig = make_subplots(
    rows=5, cols=2, 
    subplot_titles=[f"Team Name: {team}" for team in teams]
)

fig.add_trace(
    go.Scatter(y=data[teams[0]][:SUB_COUNT], line=dict(color="rgb(67,67,67)")),
    row=1, col=1,
)

fig.add_trace(
    go.Scatter(y=data[teams[1]][:SUB_COUNT], line=dict(color="rgb(67,67,67)")),
    row=1, col=2
)

fig.add_trace(
    go.Scatter(y=data[teams[2]][:SUB_COUNT], line=dict(color="rgb(67,67,67)")),
    row=2, col=1
)

fig.add_trace(
    go.Scatter(y=data[teams[3]][:SUB_COUNT], line=dict(color="rgb(67,67,67)")),
    row=2, col=2
)

fig.add_trace(
    go.Scatter(y=data[teams[4]][:SUB_COUNT], line=dict(color="rgb(67,67,67)")),
    row=3, col=1
)

fig.add_trace(
    go.Scatter(y=data[teams[5]][:SUB_COUNT], line=dict(color="rgb(67,67,67)")),
    row=3, col=2
)

fig.add_trace(
    go.Scatter(y=data[teams[6]][:SUB_COUNT], line=dict(color="rgb(67,67,67)")),
    row=4, col=1
)

fig.add_trace(
    go.Scatter(y=data[teams[7]][:SUB_COUNT], line=dict(color="rgb(67,67,67)")),
    row=4, col=2
)


fig.add_trace(
    go.Scatter(y=data[teams[8]][:SUB_COUNT], line=dict(color="rgb(67,67,67)")),
    row=5, col=1
)

fig.add_trace(
    go.Scatter(y=data[teams[9]][:SUB_COUNT], line=dict(color="rgb(67,67,67)")),
    row=5, col=2
)


fig.update_layout(height=600, width=800, title_text="Top 10 teams submisions progress")

for i in fig['layout']['annotations']:
    i['font'] = dict(size=10,color='rgb(67,67,67)')

fig.show()
# Out:
# <div>                            <div id="197455ee-52aa-4f99-9dd4-c802a75ebc63" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("197455ee-52aa-4f99-9dd4-c802a75ebc63")) {                    Plotly.newPlot(                        "197455ee-52aa-4f99-9dd4-c802a75ebc63",                        [{"line":{"color":"rgb(67,67,67)"},"y":[11.5922856904628,1.51388411236785,3.8404799176045,0.952672086630978,0.980810145614286],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"rgb(67,67,67)"},"y":[12.5532647761722,1.42733098954172,1.38266977117281,1.60274835401626,1.13504978771441],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"rgb(67,67,67)"},"y":[0.957454058395684,0.969703423646483,0.952806727210886,0.951874538274085,1.15102731774332],
# ...

# %% [markdown]
# ### Box plots

# %%
import numpy as np

x0 = np.random.randn(50)
x1 = np.random.randn(50) + 2 # shift mean

fig = go.Figure()
# Use x instead of y argument for horizontal plot
fig.add_trace(go.Box(x=x0))
fig.add_trace(go.Box(x=x1))

fig.show()
# Out:
# <div>                            <div id="669ed4e2-8131-41b7-b48d-e82c6b34a17b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("669ed4e2-8131-41b7-b48d-e82c6b34a17b")) {                    Plotly.newPlot(                        "669ed4e2-8131-41b7-b48d-e82c6b34a17b",                        [{"x":[1.0358980679876053,0.4816684631272104,-1.3919158707550372,-0.7382915237808392,0.527310129991072,-1.6593113335170906,-1.528887533815823,-1.2482227332490698,-0.40796574649182193,2.1884501730312116,0.1379868217848136,-2.104079273925933,0.4551085553023165,0.975688932361822,-0.9254836611166471,-0.8147063106812876,0.09643412728825435,0.20199097541311786,-0.15953641969792026,0.4359775363552128,-2.2550090886793814,1.0908481340647005,0.34114537514627175,-1.340438722
# ...

# %%
N = 1.8
upd_data = dict()
for item in list(data.keys()):
    upd_val = []
    for val in data[item]:
        if val < N:
            upd_val.append(val)
    upd_data[item] = upd_val

data = upd_data

# %%
fig = go.Figure()

for key in list(data.keys()):
    fig.add_trace(go.Box(
        x=data[key], 
        name=f"{key}",
        marker_color='rgb(107,174,214)',
        line_color='rgb(107,174,214)'
    ))

fig.show()
# Out:
# <div>                            <div id="a802bbad-ed57-4934-b95f-9619dcce11e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a802bbad-ed57-4934-b95f-9619dcce11e2")) {                    Plotly.newPlot(                        "a802bbad-ed57-4934-b95f-9619dcce11e2",                        [{"line":{"color":"rgb(107,174,214)"},"marker":{"color":"rgb(107,174,214)"},"name":"AfterParty","x":[1.51388411236785,0.952672086630978,0.980810145614286,0.938583779541549,0.80058799164289,0.80058799164289,0.957183375429288,0.89023019176361,0.933256336874587,1.40661378833,0.760033771959681,0.91128022465628,0.78595507541147,0.751803615214252,0.759867902553734,0.74821524914462,0.74821524914462],"type":"box"},{"line":{"color":"rgb(107,174,214)"},"marker":{"color":"rg
# ...
