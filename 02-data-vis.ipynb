# %% [markdown]
# ### Import

# %%
import os

# %%
import pandas as pd

# %%
import plotly.express as px

# %% [markdown]
# ### Consts

# %%
DATA_PATH = "data/train/"
GEO_FILE = "geo_params.csv"
SKU_FILE = "sku_final.csv"
TRAIN_FILE = "train_final.csv"

# %% [markdown]
# ### Read data

# %%
df = pd.read_csv(os.path.join(DATA_PATH, TRAIN_FILE))
df.shape
# Out:
# (27956445, 6)

# %%
df.head()
# Out:
#            ID  geoCluster    SKU        date  price  sales
# 0  RR27956447          21  32485  2021-07-08  39.69    0.9
# 1  RR27956448          21  32485  2021-07-09    NaN    NaN
# 2  RR27956449          21  32485  2021-07-10    NaN    NaN
# 3  RR27956450          21  32485  2021-07-11    NaN    NaN
# 4  RR27956451          21  32485  2021-07-12    NaN    NaN

# %%
df.price = df.price.fillna(0)
df.sales = df.sales.fillna(0)

# %% [markdown]
# ### Vis

# %%
df.SKU.unique()
# Out:
# array([ 32485,  32549,  32550, ..., 802919, 802927, 803415])

# %%
df.geoCluster.unique()
# Out:
# array([  21,   92,  112,  131,  148,  260,  298,  310,  318,  323,  446,
#         459,  488,  491,  493,  496,  508,  549,  555,  563,  565,  598,
#         613,  683,  685,  691,  744,  942,  954,  988,  999, 1241, 1246,
#        1297, 1301, 1316, 1317, 1321, 1326, 1327, 1609, 1619, 1624, 1629,
#        1634, 1635, 1664, 1672, 1673, 1677, 1689, 1690, 1702, 1704, 1737,
#        1738, 1743, 1747, 1755, 1778, 1780, 1782, 1790, 1795, 1828, 1846,
#        1851, 1860, 1862, 1867, 1868, 1879, 1887, 1894, 1928, 1934, 1935,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023,
#        2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034,
#        2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045,
#        2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056,
# ...

# %%
fig = px.line(df.loc[(df["SKU"] == 32485) & (df["geoCluster"] == 2635)], x='date', y="sales")
fig.show()
# Out:
# <div>                            <div id="295b0685-8465-4006-8d62-a3a9f730d2c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("295b0685-8465-4006-8d62-a3a9f730d2c9")) {                    Plotly.newPlot(                        "295b0685-8465-4006-8d62-a3a9f730d2c9",                        [{"hovertemplate":"date=%{x}<br>sales=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"type":"scatter","x":["2020-04-04","2020-04-05","2020-04-06","2020-04-07","2020-04-08","2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","20
# ...

# %%
fig = px.line(df.loc[(df["SKU"] == 32485) & (df["geoCluster"] == 2635)], x='date', y="price")
fig.show()
# Out:
# <div>                            <div id="9148a8bd-996e-45a0-ab6a-2a4376dbef10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9148a8bd-996e-45a0-ab6a-2a4376dbef10")) {                    Plotly.newPlot(                        "9148a8bd-996e-45a0-ab6a-2a4376dbef10",                        [{"hovertemplate":"date=%{x}<br>price=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"type":"scatter","x":["2020-04-04","2020-04-05","2020-04-06","2020-04-07","2020-04-08","2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","20
# ...
